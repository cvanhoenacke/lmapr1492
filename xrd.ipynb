# %%
from IPython.display import Image
from pymatgen import Structure
from jupyter_jsmol.pymatgen import quick_view
from pymatgen.ext.matproj import MPRester
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.analysis.diffraction.xrd import XRDCalculator

# %%
with MPRester("xAixBxXBVwN8D32SEfC8") as m:
    structure = m.get_structure_by_material_id("mp-10378")

# %%
calculator = XRDCalculator(1.54060, 1)
pattern = calculator.get_pattern(structure)

# %%
print("Premier pic")
print("Angle 2Θ:", pattern.x[0])
print("Intensité:", pattern.y[0])
print("hkl:", pattern.hkls[0])
print("d:", pattern.d_hkls[0])
# Out:
# Premier pic
# Angle 2Θ: 16.406308624771402
# Intensité: 0.062037839771172845
# hkl: [{'hkl': (1, 1, 1), 'multiplicity': 8}]
# d: 5.398664957828124

# %%
print("Deuxième pic")
print("Angle 2Θ:", pattern.x[1])
print("Intensité:", pattern.y[1])
print("hkl:", pattern.hkls[1])
print("d:", pattern.d_hkls[1])
# Out:
# Deuxième pic
# Angle 2Θ: 18.966193378019852
# Intensité: 0.034455625590225976
# hkl: [{'hkl': (2, 0, 0), 'multiplicity': 6}]
# d: 4.675381

# %%
print("Troisième pic")
print("Angle 2Θ:", pattern.x[2])
print("Intensité:", pattern.y[2])
print("hkl:", pattern.hkls[2])
print("d:", pattern.d_hkls[2])
# Out:
# Troisième pic
# Angle 2Θ: 26.94764213247891
# Intensité: 100.0
# hkl: [{'hkl': (2, 2, 0), 'multiplicity': 12}]
# d: 3.305993609730742

# %%
calculator.show_plot(structure, two_theta_range=(0,30))
